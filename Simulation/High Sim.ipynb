# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('High_train.csv')

# %%
data
# Out:
#       AGE  HEALTH_CHANGE  HBP  DIABETES  CANCER  LUNGS  HEART_ATTACK  STROKE  \
# 0      68             -1    0         0       0      0             0       0
# 1      70              1    0         0       0      0             0       0
# 2      70              1    0         0       0      0             0       0
# 3      72             -1    0         0       0      0             0       0
# 4      74             -1    0         0       0      0             0       0
# ...   ...            ...  ...       ...     ...    ...           ...     ...
# 2738   73              0    0         0       0      0             0       0
# 2739   72              1    0         0       0      0             0       0
# 2740   71              0    0         0       0      0             0       0
# 2741   73              0    0         0       0      0             0       0
# 2742   75              0    0         0       0      0             0       0
#
#       PSYCH  ARTHRITIS  ...  DOCTOR  NURSING_HOME  SHOCK2  percent_increase  \
# 0         0          0  ...       8             0       0             0.244
# 1         0          0  ...      10             0       0             0.126
# 2         0          0  ...       6             0       1             1.996
# 3         0          0  ...       4             0       0             0.451
# 4         0          0  ...       0             0       0             0.069
# ...     ...        ...  ...     ...           ...     ...               ...
# 2738      0          0  ...       4             0       0             0.012
# 2739      0          0  ...       3             0       1             1.192
# 2740      0          0  ...       0             0       0            -0.189
# 2741      0          0  ...       3             0       0            -0.064
# 2742      0          0  ...       5             0       0             0.082
#
#       WEIGHT  percent_increase.1  LAST_YEAR  SPEND_SS  SHOCK2.1     HHIDPN
# 0     5465.0               0.244   0.037382  0.180110         0   10004040
# 1     5836.0               0.126   0.180110  0.257887         0   10004040
# 2     4945.0               1.996   0.036381  0.108986         1   10059030
# 3     5856.0               0.451   1.808035  0.568987         0   10477020
# 4     6006.0               0.069   0.568987  0.460731         0   10477020
# ...      ...                 ...        ...       ...       ...        ...
# 2738  2270.0               0.012   0.169306  0.088629         0  907283020
# 2739  1492.0               1.192   0.047311  0.103692         1  910041020
# 2740  1872.0              -0.189   0.079937  0.064810         0  914149020
# 2741  2246.0              -0.064   0.064810  0.053875         0  914149020
# 2742  2535.0               0.082   0.053875  0.115139         0  914149020
#
# [2743 rows x 25 columns]

# %%
data.describe()
# Out:
#                AGE  HEALTH_CHANGE     HBP  DIABETES  CANCER   LUNGS  \
# count  2743.000000    2743.000000  2743.0    2743.0  2743.0  2743.0
# mean     74.403208       0.029165     0.0       0.0     0.0     0.0
# std       6.931994       0.795150     0.0       0.0     0.0     0.0
# min      65.000000      -4.000000     0.0       0.0     0.0     0.0
# 25%      69.000000       0.000000     0.0       0.0     0.0     0.0
# 50%      73.000000       0.000000     0.0       0.0     0.0     0.0
# 75%      78.000000       0.000000     0.0       0.0     0.0     0.0
# max     102.000000       4.000000     0.0       0.0     0.0     0.0
#
#        HEART_ATTACK  STROKE   PSYCH  ARTHRITIS  ...       DOCTOR  \
# count        2743.0  2743.0  2743.0     2743.0  ...  2743.000000
# mean            0.0     0.0     0.0        0.0  ...     4.488881
# std             0.0     0.0     0.0        0.0  ...     5.087112
# min             0.0     0.0     0.0        0.0  ...     0.000000
# 25%             0.0     0.0     0.0        0.0  ...     2.000000
# 50%             0.0     0.0     0.0        0.0  ...     3.000000
# 75%             0.0     0.0     0.0        0.0  ...     6.000000
# max             0.0     0.0     0.0        0.0  ...    50.000000
#
#        NURSING_HOME       SHOCK2  percent_increase        WEIGHT  \
# count   2743.000000  2743.000000       2743.000000   2743.000000
# mean       0.691214     0.093693          1.402272   3828.453518
# std       10.965357     0.291454         31.785603   2132.316117
# min        0.000000     0.000000         -0.998000      0.000000
# 25%        0.000000     0.000000         -0.061000   2636.000000
# 50%        0.000000     0.000000         -0.011000   3426.000000
# 75%        0.000000     0.000000          0.110500   4390.000000
# max      270.000000     1.000000       1629.336000  20348.000000
#
#        percent_increase.1    LAST_YEAR     SPEND_SS     SHOCK2.1        HHIDPN
# count         2743.000000  2743.000000  2743.000000  2743.000000  2.743000e+03
# mean             1.402272     0.173622     0.160994     0.093693  1.063690e+08
# std             31.785603     0.399007     0.408220     0.291454  9.142596e+07
# min             -0.998000     0.000000     0.000142     0.000000  1.000404e+07
# 25%             -0.061000     0.023267     0.022408     0.000000  3.910701e+07
# 50%             -0.011000     0.062817     0.053789     0.000000  7.576401e+07
# 75%              0.110500     0.176810     0.148908     0.000000  2.024790e+08
# max           1629.336000     7.876969     8.058472     1.000000  9.141490e+08
#
# [8 rows x 25 columns]

# %% [markdown]
# Simulation 2

# %%
data.columns
# Out:
# Index(['AGE', 'HEALTH_CHANGE', 'HBP', 'DIABETES', 'CANCER', 'LUNGS',
#        'HEART_ATTACK', 'STROKE', 'PSYCH', 'ARTHRITIS', 'OUT_PT', 'DRUGS',
#        'HOME_CARE', 'SPECIAL_FAC', 'HOSPITAL', 'DOCTOR', 'NURSING_HOME',
#        'SHOCK2', 'percent_increase', 'WEIGHT', 'percent_increase.1',
#        'LAST_YEAR', 'SPEND_SS', 'SHOCK2.1', 'HHIDPN'],
#       dtype='object')

# %%
from fitter import Fitter, get_common_distributions, get_distributions
def find_best_distribution(data, variable_name):

    variable_data = data[variable_name].dropna()
    f = Fitter(variable_data, distributions=get_common_distributions())
    f.fit()
    f.summary()
    return f

variable_names = ['HEALTH_CHANGE', 'HBP', 'DIABETES', 'CANCER',
       'LUNGS', 'HEART_ATTACK', 'STROKE', 'PSYCH', 'ARTHRITIS', 'OUT_PT',
       'DRUGS', 'HOME_CARE', 'SPECIAL_FAC', 'HOSPITAL', 'DOCTOR',
       'NURSING_HOME']

distribution_params = {}
for variable in variable_names:
    print(f"Analyzing {variable}")
    dist = find_best_distribution(data, variable)
    distribution_params[variable] = dist.get_best(method='sumsquare_error')
    print(dist.get_best(method='sumsquare_error'))
# Out:
# 2024-04-24 17:45:49.189 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=59.34345)
# 2024-04-24 17:45:49.190 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=63.560577)
# 2024-04-24 17:45:49.201 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=62.789673)
# 2024-04-24 17:45:49.224 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=61.906868)
# 2024-04-24 17:45:49.229 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=62.740309)
# Analyzing HEALTH_CHANGE
# 2024-04-24 17:45:49.377 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=64.352173)
# 2024-04-24 17:45:49.448 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=60.232128)
# 2024-04-24 17:45:49.472 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=59.35435)
# 2024-04-24 17:45:49.483 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=59.407931)
# 2024-04-24 17:45:49.536 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=59.342122)
# 2024-04-24 17:45:49.666 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=nan)
# 2024-04-24 17:45:49.677 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=nan)
# 2024-04-24 17:45:49.679 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=nan)
# 2024-04-24 17:45:49.679 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED gamma distribution (taking more than 30 seconds)
# 2024-04-24 17:45:49.723 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=10000.0)
# {'lognorm': {'s': 0.005349055315894618, 'loc': -148.28192577198934, 'scale': 148.30933255871906}}
# Analyzing HBP
# 2024-04-24 17:45:49.864 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=10000.0)
# 2024-04-24 17:45:49.958 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=8457.78211)
# 2024-04-24 17:45:49.978 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=10000.0)
# 2024-04-24 17:45:49.995 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=7921.970976)
# 2024-04-24 17:45:50.015 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=10000.0)
# 2024-04-24 17:45:50.090 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=nan)
# 2024-04-24 17:45:50.092 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=nan)
# 2024-04-24 17:45:50.092 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=nan)
# 2024-04-24 17:45:50.135 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED gamma distribution (taking more than 30 seconds)
# 2024-04-24 17:45:50.158 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=10000.0)
# {'exponpow': {'b': 0.12820523871161066, 'loc': -8.41129344563595e-30, 'scale': 0.9530620703276311}}
# Analyzing DIABETES
# 2024-04-24 17:45:50.293 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=10000.0)
# 2024-04-24 17:45:50.389 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=8457.78211)
# 2024-04-24 17:45:50.417 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=10000.0)
# 2024-04-24 17:45:50.438 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=7921.970976)
# 2024-04-24 17:45:50.456 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=10000.0)
# 2024-04-24 17:45:50.599 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=nan)
# 2024-04-24 17:45:50.604 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=nan)
# 2024-04-24 17:45:50.606 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=nan)
# 2024-04-24 17:45:50.621 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED gamma distribution (taking more than 30 seconds)
# 2024-04-24 17:45:50.653 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=10000.0)
# {'exponpow': {'b': 0.12820523871161066, 'loc': -8.41129344563595e-30, 'scale': 0.9530620703276311}}
# Analyzing CANCER
# 2024-04-24 17:45:50.808 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=10000.0)
# 2024-04-24 17:45:50.882 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=8457.78211)
# 2024-04-24 17:45:50.906 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=10000.0)
# 2024-04-24 17:45:50.925 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=7921.970976)
# 2024-04-24 17:45:50.949 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=10000.0)
# 2024-04-24 17:45:51.025 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=nan)
# 2024-04-24 17:45:51.042 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=nan)
# 2024-04-24 17:45:51.043 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=nan)
# 2024-04-24 17:45:51.059 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED gamma distribution (taking more than 30 seconds)
# 2024-04-24 17:45:51.075 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=10000.0)
# {'exponpow': {'b': 0.12820523871161066, 'loc': -8.41129344563595e-30, 'scale': 0.9530620703276311}}
# Analyzing LUNGS
# 2024-04-24 17:45:51.205 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=10000.0)
# 2024-04-24 17:45:51.296 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=8457.78211)
# 2024-04-24 17:45:51.309 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=10000.0)
# 2024-04-24 17:45:51.329 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=7921.970976)
# 2024-04-24 17:45:51.359 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=10000.0)
# 2024-04-24 17:45:51.457 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=nan)
# 2024-04-24 17:45:51.462 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=nan)
# 2024-04-24 17:45:51.464 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=nan)
# 2024-04-24 17:45:51.473 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED gamma distribution (taking more than 30 seconds)
# 2024-04-24 17:45:51.500 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=10000.0)
# {'exponpow': {'b': 0.12820523871161066, 'loc': -8.41129344563595e-30, 'scale': 0.9530620703276311}}
# Analyzing HEART_ATTACK
# 2024-04-24 17:45:51.723 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=10000.0)
# 2024-04-24 17:45:51.792 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=8457.78211)
# 2024-04-24 17:45:51.822 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=10000.0)
# 2024-04-24 17:45:51.842 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=7921.970976)
# 2024-04-24 17:45:51.860 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=10000.0)
# 2024-04-24 17:45:51.948 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=nan)
# 2024-04-24 17:45:51.948 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=nan)
# 2024-04-24 17:45:51.948 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=nan)
# 2024-04-24 17:45:51.960 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED gamma distribution (taking more than 30 seconds)
# 2024-04-24 17:45:51.992 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=10000.0)
# 2024-04-24 17:45:52.127 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=10000.0)
# {'exponpow': {'b': 0.12820523871161066, 'loc': -8.41129344563595e-30, 'scale': 0.9530620703276311}}
# Analyzing STROKE
# 2024-04-24 17:45:52.217 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=8457.78211)
# 2024-04-24 17:45:52.240 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=10000.0)
# 2024-04-24 17:45:52.268 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=7921.970976)
# 2024-04-24 17:45:52.282 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=10000.0)
# 2024-04-24 17:45:52.369 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=nan)
# 2024-04-24 17:45:52.372 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=nan)
# 2024-04-24 17:45:52.372 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=nan)
# 2024-04-24 17:45:52.417 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED gamma distribution (taking more than 30 seconds)
# 2024-04-24 17:45:52.425 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=10000.0)
# {'exponpow': {'b': 0.12820523871161066, 'loc': -8.41129344563595e-30, 'scale': 0.9530620703276311}}
# Analyzing PSYCH
# 2024-04-24 17:45:52.597 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=10000.0)
# 2024-04-24 17:45:52.681 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=8457.78211)
# 2024-04-24 17:45:52.704 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=10000.0)
# 2024-04-24 17:45:52.727 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=7921.970976)
# 2024-04-24 17:45:52.745 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=10000.0)
# 2024-04-24 17:45:52.824 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=nan)
# 2024-04-24 17:45:52.837 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=nan)
# 2024-04-24 17:45:52.840 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=nan)
# 2024-04-24 17:45:52.910 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=10000.0)
# 2024-04-24 17:45:52.923 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED gamma distribution (taking more than 30 seconds)
# {'exponpow': {'b': 0.12820523871161066, 'loc': -8.41129344563595e-30, 'scale': 0.9530620703276311}}
# Analyzing ARTHRITIS
# 2024-04-24 17:45:53.091 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=10000.0)
# 2024-04-24 17:45:53.173 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=8457.78211)
# 2024-04-24 17:45:53.192 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=10000.0)
# 2024-04-24 17:45:53.221 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=7921.970976)
# 2024-04-24 17:45:53.240 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=10000.0)
# 2024-04-24 17:45:53.314 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=6459.545046)
# 2024-04-24 17:45:53.323 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=6975.59558)
# 2024-04-24 17:45:53.327 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=6979.572448)
# 2024-04-24 17:45:53.331 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=6945.376901)
# {'exponpow': {'b': 0.12820523871161066, 'loc': -8.41129344563595e-30, 'scale': 0.9530620703276311}}
# Analyzing OUT_PT
# 2024-04-24 17:45:53.534 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=7079.572448)
# 2024-04-24 17:45:53.664 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=3578.329379)
# 2024-04-24 17:45:53.670 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=6449.785514)
# 2024-04-24 17:45:53.685 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=7023.699426)
# 2024-04-24 17:45:53.705 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=7079.572448)
# 2024-04-24 17:45:53.709 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=6506.657895)
# 2024-04-24 17:45:53.791 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=nan)
# 2024-04-24 17:45:53.802 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=nan)
# 2024-04-24 17:45:53.807 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=nan)
# 2024-04-24 17:45:53.813 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED gamma distribution (taking more than 30 seconds)
# 2024-04-24 17:45:53.844 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=10000.0)
# {'gamma': {'a': 0.2807105728333148, 'loc': -1.483345334687757e-29, 'scale': 0.07872429332212608}}
# Analyzing DRUGS
# 2024-04-24 17:45:53.992 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=10000.0)
# 2024-04-24 17:45:54.075 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=8457.78211)
# 2024-04-24 17:45:54.101 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=10000.0)
# 2024-04-24 17:45:54.117 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=7921.970976)
# 2024-04-24 17:45:54.141 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=10000.0)
# 2024-04-24 17:45:54.236 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=9069.364267)
# 2024-04-24 17:45:54.236 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=5571.122902)
# 2024-04-24 17:45:54.247 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=9319.987828)
# 2024-04-24 17:45:54.265 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=8940.212316)
# {'exponpow': {'b': 0.12820523871161066, 'loc': -8.41129344563595e-30, 'scale': 0.9530620703276311}}
# Analyzing HOME_CARE
# 2024-04-24 17:45:54.523 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=9419.987828)
# 2024-04-24 17:45:54.651 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=6570.551415)
# 2024-04-24 17:45:54.687 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=8261.826307)
# 2024-04-24 17:45:54.729 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=9364.049971)
# 2024-04-24 17:45:54.734 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=8179.689528)
# 2024-04-24 17:45:54.752 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=9419.987828)
# 2024-04-24 17:45:54.934 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=8499.569292)
# 2024-04-24 17:45:54.934 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=8610.614458)
# 2024-04-24 17:45:54.934 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=6929.736328)
# 2024-04-24 17:45:54.959 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=8428.704201)
# {'expon': {'loc': 0.0, 'scale': 0.02989427633977397}}
# Analyzing SPECIAL_FAC
# 2024-04-24 17:45:55.147 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=8710.614458)
# 2024-04-24 17:45:55.246 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=7110.971441)
# 2024-04-24 17:45:55.260 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=7769.828975)
# 2024-04-24 17:45:55.277 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=8654.69131)
# 2024-04-24 17:45:55.297 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=8020.521178)
# 2024-04-24 17:45:55.324 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=8710.614458)
# 2024-04-24 17:45:55.406 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=0.621869)
# 2024-04-24 17:45:55.419 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=2.583351)
# 2024-04-24 17:45:55.426 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=3.026612)
# 2024-04-24 17:45:55.443 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=2.425497)
# {'expon': {'loc': 0.0, 'scale': 0.06926722566532993}}
# Analyzing HOSPITAL
# 2024-04-24 17:45:55.620 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=3.066612)
# 2024-04-24 17:45:55.723 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=2.203367)
# 2024-04-24 17:45:55.740 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=2.042846)
# 2024-04-24 17:45:55.753 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=3.044076)
# 2024-04-24 17:45:55.780 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=1.619644)
# 2024-04-24 17:45:55.816 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=2.843584)
# 2024-04-24 17:45:55.906 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=0.232294)
# 2024-04-24 17:45:55.906 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=0.285175)
# 2024-04-24 17:45:55.914 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=0.400087)
# 2024-04-24 17:45:55.926 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=0.265378)
# 2024-04-24 17:45:55.979 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=0.248944)
# {'expon': {'loc': 0.0, 'scale': 0.5679912504557054}}
# Analyzing DOCTOR
# 2024-04-24 17:45:56.186 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=0.237292)
# 2024-04-24 17:45:56.206 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=0.409488)
# 2024-04-24 17:45:56.224 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=0.627919)
# 2024-04-24 17:45:56.237 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=0.374165)
# 2024-04-24 17:45:56.264 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=0.258139)
# 2024-04-24 17:45:56.341 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=0.112311)
# 2024-04-24 17:45:56.341 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=0.025844)
# 2024-04-24 17:45:56.354 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=0.132524)
# 2024-04-24 17:45:56.373 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=0.103436)
# {'expon': {'loc': 0.0, 'scale': 4.488880787458987}}
# Analyzing NURSING_HOME
# 2024-04-24 17:45:56.589 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=0.133895)
# 2024-04-24 17:45:56.677 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=0.126822)
# 2024-04-24 17:45:56.677 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=0.0911)
# 2024-04-24 17:45:56.709 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=0.133133)
# 2024-04-24 17:45:56.729 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=0.097349)
# 2024-04-24 17:45:56.767 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=0.133895)
# {'expon': {'loc': 0.0, 'scale': 0.6912139992708713}}

# %%
shock_data = data[data['SHOCK2']==1]
no_shock_data = data[data['SHOCK2']==0]
variable_names = ['SPEND_SS']
spending = [shock_data, no_shock_data]
spending_results = {}
for i in range(2):
    spending_results[i] = find_best_distribution(spending[i], 'SPEND_SS')
    print(spending_results[i].get_best(method='sumsquare_error'))
# Out:
# 2024-04-24 17:46:04.940 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=5.855172)
# 2024-04-24 17:46:04.966 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=20.610193)
# 2024-04-24 17:46:04.975 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=11.042194)
# 2024-04-24 17:46:04.997 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=18.884128)
# 2024-04-24 17:46:04.997 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=25.935665)
# 2024-04-24 17:46:05.016 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=3.890829)
# 2024-04-24 17:46:05.115 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=0.554757)
# 2024-04-24 17:46:05.122 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=4.901667)
# 2024-04-24 17:46:05.156 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=5.793833)
# 2024-04-24 17:46:05.162 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=9.694484)
# 2024-04-24 17:46:05.242 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=15.215021)
# 2024-04-24 17:46:05.258 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=74.652656)
# 2024-04-24 17:46:05.261 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=101.137681)
# 2024-04-24 17:46:05.269 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=66.843425)
# 2024-04-24 17:46:05.334 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=1.108404)
# 2024-04-24 17:46:05.339 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=56.452703)
# {'lognorm': {'s': 1.4842284657418778, 'loc': 0.0028795561677409723, 'scale': 0.14634986818090245}}
# 2024-04-24 17:46:05.435 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=0.320681)
# 2024-04-24 17:46:05.508 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=64.675893)
# 2024-04-24 17:46:05.518 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=34.334414)
# 2024-04-24 17:46:05.544 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=37.755378)
# {'lognorm': {'s': 1.397378477239125, 'loc': -0.0005136717056804268, 'scale': 0.05081397099687181}}

# %%
from sklearn.linear_model import LogisticRegression
def modelling(data, predictors, response):
    # Create a lagged version of 'SHOCK2' to use as the target variable
    data['response_next'] = data.groupby('HHIDPN')[response].shift(-1)
    
    
    data_clean = data.dropna(subset=predictors + ['response_next'])
    
    X = data_clean[predictors]
    y = data_clean['response_next']
    
    model = LogisticRegression(max_iter=1000, class_weight='balanced')
    model.fit(X, y)
    
    return model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

train = pd.read_csv('ss_train_shock.csv')
test = pd.read_csv('ss_test_shock.csv')
def modelling_linear(data, data_test, predictors, response):
    data['response_next'] = data.groupby('HHIDPN')[response].shift(-1)
    data_test['response_next'] = data_test.groupby('HHIDPN')[response].shift(-1)
    data_clean = data.dropna(subset=predictors + ['response_next'])
    
    X_train = data_clean[predictors]
    y_train = data_clean['response_next']
    X_test = data_test[predictors]
    y_test = data_test['response_next']
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    # Predict on the test set
    y_pred = model.predict(X_test)
    
    # Calculate residuals
    residuals = y_test - y_pred

    return model, residuals

# %%
# def modelling_linear(data, predictors, response):
#     data['response_next'] = data.groupby('HHIDPN')[response].shift(-1)
#     data_clean = data.dropna(subset=predictors + ['response_next'])
    
#     X = data_clean[predictors]
#     y = data_clean['response_next']
    
#     pipeline = Pipeline([
#         ('scaler', StandardScaler()),
#         ('model', LinearRegression())
#     ])
    
#     pipeline.fit(X, y)
    
#     return pipeline

# %%
predictors = ['AGE', 'HEALTH_CHANGE', 'HBP', 'STROKE', 'ARTHRITIS', 'DRUGS', 'SPECIAL_FAC', 'HOSPITAL', 'DOCTOR', 'NURSING_HOME']
response = 'SHOCK2'
shock_model = modelling(data, predictors, response)

# %%
yes_pred = ['AGE','PSYCH', 'DRUGS', 'HOME_CARE', 'HOSPITAL', 'DOCTOR', 'NURSING_HOME']
spend_response = 'SPEND_SS'
yes_model, yes_resid = modelling_linear(train, test, yes_pred, spend_response)

# %%
no_pred = ['AGE','HEALTH_CHANGE', 'DRUGS', 'HOME_CARE', 'DOCTOR', 'NURSING_HOME']
no_model, no_resid = modelling_linear(train, test, no_pred, spend_response)

# %%
from scipy import stats

def simulate_individual_data(num_individuals, start_age, end_age, distribution_params):
    simulated_complete_data = pd.DataFrame()

    # Simulate data for each individual
    for person_id in range(1, num_individuals + 1):
        # Initialize a DataFrame for the current individual's data across the specified age range
        individual_data = pd.DataFrame({
            'AGE': range(start_age, end_age + 1),
            'HHIDPN': person_id  # Assign the unique person ID to each row
        })

        # Simulate the data for each variable according to the distribution parameters
        for variable, params_dict in distribution_params.items():
            dist_name, params = next(iter(params_dict.items()))  # Get the distribution and its parameters
            dist = getattr(stats, dist_name)  
            individual_data[variable] = dist.rvs(size=end_age - start_age + 1, **params)
        
        simulated_complete_data = pd.concat([simulated_complete_data, individual_data], ignore_index=True)

    return simulated_complete_data

# Example usage
num_individuals = 10000

stacked_simulation = simulate_individual_data(num_individuals, 65, 90, distribution_params)
stacked_simulation
# Out:
#         AGE  HHIDPN  HEALTH_CHANGE           HBP      DIABETES        CANCER  \
# 0        65       1       1.066195  8.325229e-10  4.673816e-01  1.612405e-06
# 1        66       1      -0.008548  6.528252e-01  9.955443e-11  1.046297e-06
# 2        67       1      -0.305616  4.487292e-01  1.160150e-02  7.240347e-01
# 3        68       1      -1.716647  1.885078e-03  5.251163e-06  6.974350e-01
# 4        69       1      -0.794593  3.168594e-03  5.183352e-05  3.316030e+00
# ...     ...     ...            ...           ...           ...           ...
# 259995   86   10000       0.884128  2.166438e-01  1.275526e+01  3.494781e-10
# 259996   87   10000       0.376079  1.679669e+01  3.963346e-01  6.553957e+01
# 259997   88   10000      -0.475777  5.294675e-03  3.423378e+01  2.420611e-02
# 259998   89   10000      -0.229474  1.178775e+00  3.140102e-02  1.152248e-04
# 259999   90   10000      -0.048067  8.971449e+00  8.585648e-07  1.938986e-09
#
#                LUNGS  HEART_ATTACK        STROKE         PSYCH     ARTHRITIS  \
# 0       4.730631e-05  1.105598e-15  5.124568e-13  5.643292e-04  5.377949e-13
# 1       8.944010e-02  1.496717e-03  1.334158e+00  3.215188e-06  6.051513e-13
# 2       2.051407e-03  3.930215e-01  5.606329e-05  3.153851e-02  4.001830e-02
# 3       2.052540e+00  1.608261e+01  4.206337e-02  9.863098e-01  4.938049e-04
# 4       6.151321e+00  8.927952e-01  3.785376e-01  3.858038e-10  4.413104e-04
# ...              ...           ...           ...           ...           ...
# 259995  6.356989e+00  6.274883e-04  5.212447e-02  7.702425e-03  7.387313e-04
# 259996  1.536638e+01  6.649018e-02  2.264516e-01  3.866598e-01  1.022361e-04
# 259997  5.588528e-06  1.860147e-08  3.126597e-01  4.047883e-09  1.178288e+00
# 259998  2.314206e-02  5.080199e-09  3.370720e-03  3.309126e-01  4.963567e+00
# 259999  7.570706e-09  8.979600e-03  6.039823e-03  2.257064e+00  4.426509e-01
#
#           OUT_PT         DRUGS  HOME_CARE  SPECIAL_FAC  HOSPITAL     DOCTOR  \
# 0       0.110730  5.431590e-05   0.009189     0.023952  0.181907   4.051215
# 1       0.000097  7.664607e-08   0.038749     0.260361  0.270536   3.792400
# 2       0.000122  2.729780e-08   0.012188     0.383557  0.526725  11.038912
# 3       0.000002  1.603102e+00   0.014194     0.013869  1.502435  13.884997
# 4       0.014309  1.673574e-08   0.005717     0.016541  0.098841   1.337665
# ...          ...           ...        ...          ...       ...        ...
# 259995  0.120420  1.404837e-03   0.039766     0.148124  0.480495   5.558957
# 259996  0.020212  2.965641e-04   0.007808     0.011483  0.011054   1.938622
# 259997  0.000240  1.116389e+02   0.094810     0.003957  0.153741  10.759019
# 259998  0.009621  8.416965e-01   0.042498     0.008277  0.684616   6.239118
# 259999  0.000040  4.986055e-01   0.002093     0.016015  1.096085   2.806782
#
#         NURSING_HOME
# 0           0.078348
# 1           0.542809
# 2           1.268991
# 3           0.466461
# 4           0.048892
# ...              ...
# 259995      1.147375
# 259996      0.386347
# 259997      2.716956
# 259998      0.833148
# 259999      0.613298
#
# [260000 rows x 18 columns]

# %%
def add_shock_predictions(simulated_data, shock_model, predictors):
    
    predicted_shocks = shock_model.predict(simulated_data[predictors])
    
    simulated_data['SHOCK2'] = predicted_shocks
    
    return simulated_data

simulated_data_with_shock = add_shock_predictions(stacked_simulation, shock_model, predictors)

simulated_data_with_shock
# Out:
#         AGE  HHIDPN  HEALTH_CHANGE           HBP      DIABETES        CANCER  \
# 0        65       1       1.066195  8.325229e-10  4.673816e-01  1.612405e-06
# 1        66       1      -0.008548  6.528252e-01  9.955443e-11  1.046297e-06
# 2        67       1      -0.305616  4.487292e-01  1.160150e-02  7.240347e-01
# 3        68       1      -1.716647  1.885078e-03  5.251163e-06  6.974350e-01
# 4        69       1      -0.794593  3.168594e-03  5.183352e-05  3.316030e+00
# ...     ...     ...            ...           ...           ...           ...
# 259995   86   10000       0.884128  2.166438e-01  1.275526e+01  3.494781e-10
# 259996   87   10000       0.376079  1.679669e+01  3.963346e-01  6.553957e+01
# 259997   88   10000      -0.475777  5.294675e-03  3.423378e+01  2.420611e-02
# 259998   89   10000      -0.229474  1.178775e+00  3.140102e-02  1.152248e-04
# 259999   90   10000      -0.048067  8.971449e+00  8.585648e-07  1.938986e-09
#
#                LUNGS  HEART_ATTACK        STROKE         PSYCH     ARTHRITIS  \
# 0       4.730631e-05  1.105598e-15  5.124568e-13  5.643292e-04  5.377949e-13
# 1       8.944010e-02  1.496717e-03  1.334158e+00  3.215188e-06  6.051513e-13
# 2       2.051407e-03  3.930215e-01  5.606329e-05  3.153851e-02  4.001830e-02
# 3       2.052540e+00  1.608261e+01  4.206337e-02  9.863098e-01  4.938049e-04
# 4       6.151321e+00  8.927952e-01  3.785376e-01  3.858038e-10  4.413104e-04
# ...              ...           ...           ...           ...           ...
# 259995  6.356989e+00  6.274883e-04  5.212447e-02  7.702425e-03  7.387313e-04
# 259996  1.536638e+01  6.649018e-02  2.264516e-01  3.866598e-01  1.022361e-04
# 259997  5.588528e-06  1.860147e-08  3.126597e-01  4.047883e-09  1.178288e+00
# 259998  2.314206e-02  5.080199e-09  3.370720e-03  3.309126e-01  4.963567e+00
# 259999  7.570706e-09  8.979600e-03  6.039823e-03  2.257064e+00  4.426509e-01
#
#           OUT_PT         DRUGS  HOME_CARE  SPECIAL_FAC  HOSPITAL     DOCTOR  \
# 0       0.110730  5.431590e-05   0.009189     0.023952  0.181907   4.051215
# 1       0.000097  7.664607e-08   0.038749     0.260361  0.270536   3.792400
# 2       0.000122  2.729780e-08   0.012188     0.383557  0.526725  11.038912
# 3       0.000002  1.603102e+00   0.014194     0.013869  1.502435  13.884997
# 4       0.014309  1.673574e-08   0.005717     0.016541  0.098841   1.337665
# ...          ...           ...        ...          ...       ...        ...
# 259995  0.120420  1.404837e-03   0.039766     0.148124  0.480495   5.558957
# 259996  0.020212  2.965641e-04   0.007808     0.011483  0.011054   1.938622
# 259997  0.000240  1.116389e+02   0.094810     0.003957  0.153741  10.759019
# 259998  0.009621  8.416965e-01   0.042498     0.008277  0.684616   6.239118
# 259999  0.000040  4.986055e-01   0.002093     0.016015  1.096085   2.806782
#
#         NURSING_HOME  SHOCK2
# 0           0.078348     0.0
# 1           0.542809     0.0
# 2           1.268991     0.0
# 3           0.466461     0.0
# 4           0.048892     1.0
# ...              ...     ...
# 259995      1.147375     0.0
# 259996      0.386347     1.0
# 259997      2.716956     1.0
# 259998      0.833148     0.0
# 259999      0.613298     0.0
#
# [260000 rows x 19 columns]

# %%
def add_spend_ss_predictions(simulated_data, yes_model, no_model, yes_pred, no_pred):
    simulated_data['SPEND_SS'] = 0.0

    shock_indices = simulated_data[simulated_data['SHOCK2'] == 1].index
    yes_predictions = yes_model.predict(simulated_data.loc[shock_indices, yes_pred])
    yes_random_residuals = np.random.choice(yes_resid, size=len(shock_indices), replace=True)
    simulated_data.loc[shock_indices, 'SPEND_SS'] = yes_predictions + yes_random_residuals

    no_shock_indices = simulated_data[simulated_data['SHOCK2'] == 0].index
    no_predictions = no_model.predict(simulated_data.loc[no_shock_indices, no_pred])
    no_random_residuals = np.random.choice(no_resid, size=len(no_shock_indices), replace=True)
    simulated_data.loc[no_shock_indices, 'SPEND_SS'] = no_predictions + no_random_residuals
    
    return simulated_data

# Example usage
simulated_data_final = add_spend_ss_predictions(simulated_data_with_shock, yes_model, no_model, yes_pred, no_pred)
simulated_data_final
# Out:
#         AGE  HHIDPN  HEALTH_CHANGE           HBP      DIABETES        CANCER  \
# 0        65       1       1.066195  8.325229e-10  4.673816e-01  1.612405e-06
# 1        66       1      -0.008548  6.528252e-01  9.955443e-11  1.046297e-06
# 2        67       1      -0.305616  4.487292e-01  1.160150e-02  7.240347e-01
# 3        68       1      -1.716647  1.885078e-03  5.251163e-06  6.974350e-01
# 4        69       1      -0.794593  3.168594e-03  5.183352e-05  3.316030e+00
# ...     ...     ...            ...           ...           ...           ...
# 259995   86   10000       0.884128  2.166438e-01  1.275526e+01  3.494781e-10
# 259996   87   10000       0.376079  1.679669e+01  3.963346e-01  6.553957e+01
# 259997   88   10000      -0.475777  5.294675e-03  3.423378e+01  2.420611e-02
# 259998   89   10000      -0.229474  1.178775e+00  3.140102e-02  1.152248e-04
# 259999   90   10000      -0.048067  8.971449e+00  8.585648e-07  1.938986e-09
#
#                LUNGS  HEART_ATTACK        STROKE         PSYCH     ARTHRITIS  \
# 0       4.730631e-05  1.105598e-15  5.124568e-13  5.643292e-04  5.377949e-13
# 1       8.944010e-02  1.496717e-03  1.334158e+00  3.215188e-06  6.051513e-13
# 2       2.051407e-03  3.930215e-01  5.606329e-05  3.153851e-02  4.001830e-02
# 3       2.052540e+00  1.608261e+01  4.206337e-02  9.863098e-01  4.938049e-04
# 4       6.151321e+00  8.927952e-01  3.785376e-01  3.858038e-10  4.413104e-04
# ...              ...           ...           ...           ...           ...
# 259995  6.356989e+00  6.274883e-04  5.212447e-02  7.702425e-03  7.387313e-04
# 259996  1.536638e+01  6.649018e-02  2.264516e-01  3.866598e-01  1.022361e-04
# 259997  5.588528e-06  1.860147e-08  3.126597e-01  4.047883e-09  1.178288e+00
# 259998  2.314206e-02  5.080199e-09  3.370720e-03  3.309126e-01  4.963567e+00
# 259999  7.570706e-09  8.979600e-03  6.039823e-03  2.257064e+00  4.426509e-01
#
#           OUT_PT         DRUGS  HOME_CARE  SPECIAL_FAC  HOSPITAL     DOCTOR  \
# 0       0.110730  5.431590e-05   0.009189     0.023952  0.181907   4.051215
# 1       0.000097  7.664607e-08   0.038749     0.260361  0.270536   3.792400
# 2       0.000122  2.729780e-08   0.012188     0.383557  0.526725  11.038912
# 3       0.000002  1.603102e+00   0.014194     0.013869  1.502435  13.884997
# 4       0.014309  1.673574e-08   0.005717     0.016541  0.098841   1.337665
# ...          ...           ...        ...          ...       ...        ...
# 259995  0.120420  1.404837e-03   0.039766     0.148124  0.480495   5.558957
# 259996  0.020212  2.965641e-04   0.007808     0.011483  0.011054   1.938622
# 259997  0.000240  1.116389e+02   0.094810     0.003957  0.153741  10.759019
# 259998  0.009621  8.416965e-01   0.042498     0.008277  0.684616   6.239118
# 259999  0.000040  4.986055e-01   0.002093     0.016015  1.096085   2.806782
#
#         NURSING_HOME  SHOCK2   SPEND_SS
# 0           0.078348     0.0  -0.198891
# 1           0.542809     0.0  -0.047321
# 2           1.268991     0.0  -0.172854
# 3           0.466461     0.0        NaN
# 4           0.048892     1.0  -0.187571
# ...              ...     ...        ...
# 259995      1.147375     0.0        NaN
# 259996      0.386347     1.0   1.024832
# 259997      2.716956     1.0  18.515758
# 259998      0.833148     0.0   0.532372
# 259999      0.613298     0.0   0.417658
#
# [260000 rows x 20 columns]

# %%
def plot_average_spending_by_age(simulated_data):
    average_spending_by_age = simulated_data.groupby('AGE')['SPEND_SS'].mean()
    plt.figure(figsize=(10, 6))
    average_spending_by_age.plot(kind='line', marker='o')
    plt.title('Average Spending by Age')
    plt.xlabel('Age')
    plt.ylabel('Average Spending')
    plt.grid(True)
    plt.show()

# Example usage with the simulated data
plot_average_spending_by_age(simulated_data_final)
